# %%
import numpy as np
import random
import pandas as pd
from tqdm import tqdm
import os
import matplotlib.pyplot as plt
from pathlib import Path

# %%
data = Path("data")

# %%
datafiler = os.listdir(data)
datafiler.sort()
datafiler
# Out:
# ['.ipynb_checkpoints',
#  'barnetallsfordeling.csv',
#  'befolkningsutvikling_2023_2063_1_5.csv',
#  'befolkningsutvikling_2063_2113_1_1.csv',
#  'befolkningsutvikling_2063_2113_1_5.csv',
#  'befolkningsutvikling_2063_2113_2_1.csv',
#  'popfordeling_2023-2063_tfr1_5.csv',
#  'popfordeling_2023-2123_tfr1_5.csv',
#  'popfordeling_2063-2113_tfr1_1.csv',
#  'popfordeling_2063-2113_tfr1_5.csv',
#  'popfordeling_2063-2113_tfr2_1.csv',
#  'populasjon_2063_tfr1_5.csv',
#  'populasjon_2113_tfr1_1.csv',
#  'populasjon_2113_tfr1_5.csv',
#  'populasjon_2113_tfr2_1.csv',
#  'populasjon_2123_tfr1_5.csv',
#  'startpop_no.csv',
#  'startpop_no_test.csv']

# %%
befolkning_23_63 = pd.read_csv(data / "befolkningsutvikling_2023_2063_1_5.csv")#.iloc[:,1:]
befolkning_23_63.tail(5)
# Out:
#       år  pop_1.5
# 36  2059  5460516
# 37  2060  5434944
# 38  2061  5407415
# 39  2062  5378160
# 40  2063  5347261

# %%
befolkning_63_23_1_5 = pd.read_csv(data / "befolkningsutvikling_2063_2113_1_5.csv")#.iloc[:,1:]
befolkning_63_23_2_1 = pd.read_csv(data / "befolkningsutvikling_2063_2113_2_1.csv")#.iloc[:,1:]
befolkning_63_23_1_1 = pd.read_csv(data / "befolkningsutvikling_2063_2113_1_1.csv")#.iloc[:,1:]

befolkning_63_23_1_5.head(5)
# Out:
#      år  pop_1.5
# 0  2063  5347261
# 1  2064  5315010
# 2  2065  5282799
# 3  2066  5250320
# 4  2067  5217996

# %%
befolkning_1_5 = pd.concat([befolkning_23_63, befolkning_63_23_1_5]).reset_index(drop=True)
befolkning_1_5
# Out:
#       år  pop_1.5
# 0   2023  5488984
# 1   2024  5499094
# 2   2025  5508432
# 3   2026  5517115
# 4   2027  5525334
# ..   ...      ...
# 87  2109  3579772
# 88  2110  3543740
# 89  2111  3508485
# 90  2112  3474149
# 91  2113  3439816
#
# [92 rows x 2 columns]

# %%
befolkning = befolkning_1_5.merge(befolkning_63_23_2_1, on ="år", how="left").merge(befolkning_63_23_1_1, on ="år", how="left")

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(befolkning.år, befolkning["pop_1.5"], color='green', alpha = 0.3, label='TFR 1.5')
ax.plot(befolkning.år, befolkning["pop_2.1"], color='blue', alpha = 0.3, label='TFR 2.1')
ax.plot(befolkning.år, befolkning["pop_1.1"], color='red', alpha = 0.3, label='TFR 1.1')

ax.set_ylim(0,6e6)
ax.set_ylabel('Befolkning')
ax.set_xlabel('År')
ax.set_title('Befolkningsutvikling i Norge fra 2024')
ax.legend()

# ax.line()

# %%
populasjon_2113_1_5 = pd.read_csv(data / 'populasjon_2113_tfr1_5.csv')
populasjon_2113_1_1 = pd.read_csv(data / 'populasjon_2113_tfr1_1.csv')
populasjon_2113_2_1 = pd.read_csv(data / 'populasjon_2113_tfr2_1.csv')

# %%
populasjon_2113_1_5
# Out:
#         sex  alder  barn
# 0         M   90.0   0.0
# 1         M   90.0   0.0
# 2         M   90.0   0.0
# 3         M   90.0   0.0
# 4         M   90.0   0.0
# ...      ..    ...   ...
# 3439811   M    0.0   0.0
# 3439812   K    0.0   0.0
# 3439813   M    0.0   0.0
# 3439814   K    0.0   0.0
# 3439815   K    0.0   0.0
#
# [3439816 rows x 3 columns]

# %%
populasjon_2113_1_5.loc[lambda x: (x.alder > 45)].barn.value_counts().sort_index().reset_index().plot( x="barn", y="count", kind="bar")
# Out:
# <Axes: xlabel='barn'>

# %%
populasjon_2113_1_5.loc[lambda x: (x.alder > 45)].barn.value_counts(normalize=True).sort_index().reset_index().plot( x="barn", y="proportion", kind="bar")
# Out:
# <Axes: xlabel='barn'>

# %%
populasjon_2113_1_5.loc[lambda x: (x.alder > 45)].barn.value_counts(normalize=True).sort_index().reset_index()
# Out:
#    barn  proportion
# 0   0.0    0.322806
# 1   1.0    0.322105
# 2   2.0    0.218059
# 3   3.0    0.097286
# 4   4.0    0.039745

# %%
import altair as alt

# %%
import altair as alt

df = populasjon_2113_1_5.loc[lambda x: (x.alder > 45)].barn.value_counts(normalize=True).sort_index().reset_index()
# 2. Create the Stacking Groups
def get_group(barn):
    """Categorizes the original child counts into the requested groups."""
    if barn in [0.0, 1.0]:
        return '0-1 children'
    elif barn in [2.0, 3.0, 4.0]:
        return '2+ children'
    # Fallback, though not needed for this specific dataset
    return 'Other'

df['group'] = df['barn'].apply(get_group)

# Create a clean string for the legend/color encoding
df['barn_str'] = df['barn'].astype(int).astype(str) + ' children'

# 3. Create and Display the Altair Chart
chart = alt.Chart(df).mark_bar().encode(
    # X-axis: The main group categories
    x=alt.X('group:N', title='Number of Children Group'),

    # Y-axis: The proportion (Altair automatically stacks segments within a group)
    y=alt.Y('proportion:Q', title='Proportion (Stacked)', axis=alt.Axis(format='.1%')),

    # Color/Stacking: The original child count (the segments)
    color=alt.Color('barn_str:N', title='Original Count', sort=['0 children', '1 children', '2 children', '3 children', '4 children']),

    # Tooltip for detailed information on hover
    tooltip=['group:N', 'barn_str:N', alt.Tooltip('proportion:Q', format='.2%')]
).properties(
    title='Proportion of Adults (>45) by Number of Children (Grouped)',
    width=400
).interactive() # Allows interactive zooming/panning

# Display the chart in the Jupyter Notebook output cell
chart
# Out:
# alt.Chart(...)

# %%
pensjonister_u_2_b = populasjon_2113_1_5.loc[lambda x: (x.alder > 67)  & (x.barn < 2)].sex.count()
pensjonister_u_2_b
# Out:
# 861491

# %%
pensjonister_o_2_b = populasjon_2113_1_5.loc[lambda x: (x.alder > 67)  & (x.barn >= 2)].sex.count()
pensjonister_o_2_b
# Out:
# 377596

# %%
arbeids_alder = populasjon_2113_2_1.loc[lambda x: (x.alder > 20) & (x.alder < 67)].sex.count()

# %%
arbeids_alder / (pensjonister_o_2_b + pensjonister_u_2_b)
# Out:
# 1.6098159370568814

# %%
arbeids_alder / pensjonister_o_2_b
# Out:
# 5.282635409273404

# %%
arbeids_alder / pensjonister_u_2_b
# Out:
# 2.3154066612419633

# %%
pop = pd.read_csv(data / 'popfordeling_2023-2123_tfr1_5.csv').iloc[:,:93]
pop
# Out:
#     sex  alder  pop_2023  pop_2024  pop_2025  pop_2026  pop_2027  pop_2028  \
# 0     K      0   25310.0   27008.0   26824.0   26391.0   26238.0   25905.0
# 1     K      1   28037.0   25308.0   27004.0   26822.0   26390.0   26236.0
# 2     K      2   26820.0   28032.0   25303.0   26996.0   26817.0   26390.0
# 3     K      3   27466.0   26814.0   28030.0   25300.0   26994.0   26815.0
# 4     K      4   27692.0   27464.0   26811.0   28021.0   25297.0   26991.0
# ..   ..    ...       ...       ...       ...       ...       ...       ...
# 215   M    105      28.0       NaN       4.0       2.0       NaN       NaN
# 216   M    106       NaN       8.0       NaN       2.0       1.0       NaN
# 217   M    107       NaN       NaN       NaN       NaN       NaN       NaN
# 218   M    108       NaN       NaN       NaN       NaN       NaN       NaN
# 219   M    109       NaN       NaN       NaN       NaN       NaN       NaN
#
#      pop_2029  pop_2030  ...  pop_2104  pop_2105  pop_2106  pop_2107  \
# 0     25543.0   25220.0  ...   12693.0   12531.0   12468.0   12327.0
# 1     25900.0   25536.0  ...   12746.0   12692.0   12531.0   12468.0
# 2     26235.0   25896.0  ...   12910.0   12746.0   12692.0   12531.0
# 3     26385.0   26230.0  ...   12963.0   12910.0   12746.0   12692.0
# 4     26814.0   26382.0  ...   13014.0   12963.0   12910.0   12746.0
# ..        ...       ...  ...       ...       ...       ...       ...
# 215       1.0       NaN  ...      14.0      11.0       8.0       7.0
# 216       NaN       NaN  ...       7.0       8.0       3.0       1.0
# 217       NaN       NaN  ...       2.0       3.0       4.0       1.0
# 218       NaN       NaN  ...       NaN       2.0       2.0       2.0
# 219       NaN       NaN  ...       NaN       NaN       NaN       1.0
#
#      pop_2108  pop_2109  pop_2110  pop_2111  pop_2112  pop_2113
# 0     12159.0   12068.0   11961.0   11806.0   11634.0   11689.0
# 1     12327.0   12159.0   12068.0   11961.0   11806.0   11634.0
# 2     12468.0   12327.0   12159.0   12067.0   11960.0   11806.0
# 3     12531.0   12467.0   12327.0   12159.0   12066.0   11960.0
# 4     12691.0   12531.0   12467.0   12327.0   12159.0   12065.0
# ..        ...       ...       ...       ...       ...       ...
# 215       5.0      11.0       9.0      14.0      16.0      13.0
# 216       4.0       2.0       3.0       2.0       7.0       6.0
# 217       NaN       1.0       NaN       NaN       1.0       3.0
# 218       NaN       NaN       NaN       NaN       NaN       NaN
# 219       1.0       NaN       NaN       NaN       NaN       NaN
#
# [220 rows x 93 columns]

# %%
pop_2 = pd.read_csv(data / 'popfordeling_2063-2113_tfr1_5.csv')
pop_2
# Out:
#     sex  alder  pop_2023  pop_2064  pop_2065  pop_2066  pop_2067  pop_2068  \
# 0     K      0   18502.0   18348.0   18078.0   18183.0   17968.0   17868.0
# 1     K      1   18768.0   18502.0   18347.0   18075.0   18181.0   17964.0
# 2     K      2   18734.0   18768.0   18502.0   18347.0   18074.0   18179.0
# 3     K      3   19065.0   18734.0   18768.0   18500.0   18347.0   18073.0
# 4     K      4   19182.0   19065.0   18734.0   18768.0   18500.0   18347.0
# ..   ..    ...       ...       ...       ...       ...       ...       ...
# 215   M    105       4.0       2.0       4.0       3.0       4.0       8.0
# 216   M    106       NaN       1.0       1.0       1.0       NaN       1.0
# 217   M    107       NaN       NaN       NaN       NaN       NaN       NaN
# 218   M    108       NaN       NaN       NaN       NaN       NaN       NaN
# 219   M    109       NaN       NaN       NaN       NaN       NaN       NaN
#
#      pop_2069  pop_2070  ...  pop_2104  pop_2105  pop_2106  pop_2107  \
# 0     17668.0   17475.0  ...   12525.0   12564.0   12397.0   12283.0
# 1     17867.0   17667.0  ...   12754.0   12524.0   12563.0   12397.0
# 2     17964.0   17865.0  ...   12766.0   12754.0   12524.0   12563.0
# 3     18177.0   17964.0  ...   12880.0   12766.0   12753.0   12524.0
# 4     18071.0   18176.0  ...   13282.0   12878.0   12766.0   12753.0
# ..        ...       ...  ...       ...       ...       ...       ...
# 215       7.0       3.0  ...       9.0       8.0       7.0      10.0
# 216       3.0       3.0  ...       2.0       2.0       2.0       1.0
# 217       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 218       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 219       NaN       NaN  ...       NaN       NaN       NaN       NaN
#
#      pop_2108  pop_2109  pop_2110  pop_2111  pop_2112  pop_2113
# 0     12210.0   12079.0   11922.0   11841.0   11655.0   11685.0
# 1     12282.0   12210.0   12079.0   11922.0   11841.0   11654.0
# 2     12397.0   12282.0   12209.0   12079.0   11921.0   11840.0
# 3     12563.0   12395.0   12282.0   12208.0   12079.0   11921.0
# 4     12524.0   12563.0   12395.0   12282.0   12208.0   12078.0
# ..        ...       ...       ...       ...       ...       ...
# 215       4.0       7.0       7.0      12.0       8.0      10.0
# 216       1.0       1.0       1.0       3.0       2.0       2.0
# 217       NaN       NaN       NaN       NaN       NaN       1.0
# 218       NaN       NaN       NaN       NaN       NaN       NaN
# 219       NaN       NaN       NaN       NaN       NaN       NaN
#
# [220 rows x 53 columns]

# %%
pop = pop[["sex","alder", "pop_2023", "pop_2113"]]
pop
# Out:
#     sex  alder  pop_2023  pop_2113
# 0     K      0   25310.0   11689.0
# 1     K      1   28037.0   11634.0
# 2     K      2   26820.0   11806.0
# 3     K      3   27466.0   11960.0
# 4     K      4   27692.0   12065.0
# ..   ..    ...       ...       ...
# 215   M    105      28.0      13.0
# 216   M    106       NaN       6.0
# 217   M    107       NaN       3.0
# 218   M    108       NaN       NaN
# 219   M    109       NaN       NaN
#
# [220 rows x 4 columns]

# %%
pop_2 = pop_2[["sex","alder", "pop_2113"]]
pop
# Out:
#     sex  alder  pop_2023  pop_2113
# 0     K      0   25310.0   11689.0
# 1     K      1   28037.0   11634.0
# 2     K      2   26820.0   11806.0
# 3     K      3   27466.0   11960.0
# 4     K      4   27692.0   12065.0
# ..   ..    ...       ...       ...
# 215   M    105      28.0      13.0
# 216   M    106       NaN       6.0
# 217   M    107       NaN       3.0
# 218   M    108       NaN       NaN
# 219   M    109       NaN       NaN
#
# [220 rows x 4 columns]

# %%
pop = pop.groupby("alder")[["pop_2023", "pop_2113"]].sum()
pop_2 = pop_2.groupby("alder")[["pop_2113"]].sum()

# %%
df = pop

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))


ax.bar(pop.index, pop['pop_2023'], color='red', alpha = 0.3, label='Populasjon 2063')
ax.bar(pop.index, pop['pop_2113'], color='blue', alpha = 0.3, label='Populasjon 2113')
# ax.barh(kvinner['alder'], -kvinner['2024'], color='orangered', label='Women')

ax.set_ylabel('Num. of people')
ax.set_xlabel('Age Group')
ax.set_title('Population and live births for different age groups in Norway (2024)')
ax.legend()


# Customizing the x-axis to show positive values for both sides
ax.set_xticks(range(0,len(df.index),5))
ax.set_xticklabels(range(0,len(df.index),5))


# plt.savefig("Figures/ASFR_2024.png", format="png", dpi=300)

plt.show()

# %%
populasjon_2113_1_5

# %%
df = pop

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))


#ax.bar(pop.index, pop['pop_2023'], color='red', alpha = 0.3, label='Populasjon 2063')
ax.bar(pop.index, pop['pop_2113'], color='blue', alpha = 0.3, label='Populasjon 2113')
ax.bar(pop_2.index, pop_2['pop_2113'], color='red', alpha = 0.3, label='Populasjon 2113')
# ax.barh(kvinner['alder'], -kvinner['2024'], color='orangered', label='Women')

ax.set_ylabel('Num. of people')
ax.set_xlabel('Age Group')
ax.set_title('Population and live births for different age groups in Norway (2024)')
ax.legend()


# Customizing the x-axis to show positive values for both sides
ax.set_xticks(range(0,len(df.index),5))
ax.set_xticklabels(range(0,len(df.index),5))


# plt.savefig("Figures/ASFR_2024.png", format="png", dpi=300)

plt.show()

# %%
df = pop

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))


#ax.bar(pop.index, pop['pop_2023'], color='red', alpha = 0.3, label='Populasjon 2063')
ax.bar(pop.index, pop['pop_2113'], color='blue', alpha = 0.3, label='Populasjon 2113')
# ax.barh(kvinner['alder'], -kvinner['2024'], color='orangered', label='Women')

ax.set_ylim(0, 85e3)
ax.set_ylabel('Num. of people')
ax.set_xlabel('Age Group')
ax.set_title('Population and live births for different age groups in Norway (2024)')
ax.legend()


# Customizing the x-axis to show positive values for both sides
ax.set_xticks(range(0,len(df.index),5))
ax.set_xticklabels(range(0,len(df.index),5))


# plt.savefig("Figures/ASFR_2024.png", format="png", dpi=300)

plt.show()

# %%
pop["diff"] = pop["pop_2050"] - pop["pop_2023"]
pop
# Out:
#        pop_2023  pop_2050   diff
# alder
# 0         520.0    1383.0  863.0
# 1         574.0    1373.0  799.0
# 2         548.0    1432.0  884.0
# 3         565.0    1423.0  858.0
# 4         572.0    1433.0  861.0
# ...         ...       ...    ...
# 105         1.0       0.0   -1.0
# 106         0.0       0.0    0.0
# 107         0.0       0.0    0.0
# 108         0.0       0.0    0.0
# 109         0.0       0.0    0.0
#
# [110 rows x 3 columns]

# %%
pop["diff"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Projects/Befolkningsfremskrivning/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pop["diff"].sum()
#
# File ~/Projects/Befolkningsfremskrivning/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Projects/Befolkningsfremskrivning/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'diff'

# %%
pop = pop.reset_index()
pop
# Out:
#      alder  pop_2023  pop_2050   diff
# 0        0     520.0    1383.0  863.0
# 1        1     574.0    1373.0  799.0
# 2        2     548.0    1432.0  884.0
# 3        3     565.0    1423.0  858.0
# 4        4     572.0    1433.0  861.0
# ..     ...       ...       ...    ...
# 105    105       1.0       0.0   -1.0
# 106    106       0.0       0.0    0.0
# 107    107       0.0       0.0    0.0
# 108    108       0.0       0.0    0.0
# 109    109       0.0       0.0    0.0
#
# [110 rows x 4 columns]

# %%
bins = list(range(0, 114, 5))

# Lag bins og gi dem lesbare etiketter
pop["aldersgruppe"] = pd.cut(pop["alder"], bins=bins, right=False, include_lowest=True,
                    labels=[f"{i}-{i+4}" for i in range(0, 109, 5)])

# %%
age_groups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 age_groups
#
# NameError: name 'age_groups' is not defined

# %%
pop_binned = pop.groupby("aldersgruppe")[["pop_2023","pop_2050"]].sum().reset_index()

# %%
pop_binned
# Out:
#    aldersgruppe  pop_2023  pop_2050
# 0           0-4  277785.0  239428.0
# 1           5-9  306608.0  253695.0
# 2         10-14  331674.0  261991.0
# 3         15-19  325360.0  270828.0
# 4         20-24  333966.0  285142.0
# 5         25-29  368198.0  299704.0
# 6         30-34  394345.0  325551.0
# 7         35-39  370973.0  351647.0
# 8         40-44  357260.0  362849.0
# 9         45-49  358569.0  357522.0
# 10        50-54  381407.0  387906.0
# 11        55-59  355284.0  419128.0
# 12        60-64  316094.0  414225.0
# 13        65-69  288666.0  384135.0
# 14        70-74  255592.0  351257.0
# 15        75-79  220843.0  333133.0
# 16        80-84  128028.0  257366.0
# 17        85-89   72349.0  142535.0
# 18        90-94   35205.0   58470.0
# 19        95-99    9503.0   11469.0
# 20      100-104    1171.0    1304.0
# 21      105-109     104.0       6.0

# %%
pop_binned["diff"] = pop_binned["pop_2050"] - pop_binned["pop_2023"]
pop_binned
# Out:
#    aldersgruppe  pop_2023  pop_2050      diff
# 0           0-4  277785.0  239428.0  -38357.0
# 1           5-9  306608.0  253695.0  -52913.0
# 2         10-14  331674.0  261991.0  -69683.0
# 3         15-19  325360.0  270828.0  -54532.0
# 4         20-24  333966.0  285142.0  -48824.0
# 5         25-29  368198.0  299704.0  -68494.0
# 6         30-34  394345.0  325551.0  -68794.0
# 7         35-39  370973.0  351647.0  -19326.0
# 8         40-44  357260.0  362849.0    5589.0
# 9         45-49  358569.0  357522.0   -1047.0
# 10        50-54  381407.0  387906.0    6499.0
# 11        55-59  355284.0  419128.0   63844.0
# 12        60-64  316094.0  414225.0   98131.0
# 13        65-69  288666.0  384135.0   95469.0
# 14        70-74  255592.0  351257.0   95665.0
# 15        75-79  220843.0  333133.0  112290.0
# 16        80-84  128028.0  257366.0  129338.0
# 17        85-89   72349.0  142535.0   70186.0
# 18        90-94   35205.0   58470.0   23265.0
# 19        95-99    9503.0   11469.0    1966.0
# 20      100-104    1171.0    1304.0     133.0
# 21      105-109     104.0       6.0     -98.0

# %%
pop_binned.iloc[4:8]["diff"].sum()
# Out:
# -205438.0

# %%
pop_binned["diff"].sum()
# Out:
# 280307.0

# %%
år = 2043

fremskrivning_1 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})

fremskrivning_1["år"] = range(år, år+ len(fremskrivning_21))
fremskrivning_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 år = 2043
#       3 fremskrivning_1 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})
# ----> 5 fremskrivning_1["år"] = range(år, år+ len(fremskrivning_21))
#       6 fremskrivning_1
#
# NameError: name 'fremskrivning_21' is not defined

# %%
år = 2063

fremskrivning_2 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})

fremskrivning_2["år"] = range(år, år+ len(fremskrivning_2))
fremskrivning_2
# Out:
#         2.1    år
# 0   5632283  2063
# 1   5645971  2064
# 2   5659099  2065
# 3   5671764  2066
# 4   5683222  2067
# ..      ...   ...
# 72  4729343  2135
# 73  4731783  2136
# 74  4734443  2137
# 75  4737340  2138
# 76  4740300  2139
#
# [77 rows x 2 columns]

# %%
år = 2083

fremskrivning_3 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})

fremskrivning_3["år"] = range(år, år+ len(fremskrivning_3))
fremskrivning_3
# Out:
#         2.1    år
# 0   5096082  2083
# 1   5096219  2084
# 2   5095355  2085
# 3   5092995  2086
# 4   5088512  2087
# 5   5082098  2088
# 6   5073755  2089
# 7   5063418  2090
# 8   5050959  2091
# 9   5037069  2092
# 10  5021982  2093
# 11  5005417  2094
# 12  4987043  2095
# 13  4967039  2096
# 14  4945322  2097
# 15  4922049  2098
# 16  4897041  2099
# 17  4870268  2100
# 18  4842141  2101
# 19  4813335  2102
# 20  4784078  2103
# 21  4754650  2104
# 22  4725000  2105
# 23  4695514  2106
# 24  4666071  2107
# 25  4637368  2108
# 26  4609768  2109
# 27  4583541  2110
# 28  4558724  2111
# 29  4535056  2112
# 30  4513337  2113
# 31  4493064  2114
# 32  4474148  2115
# 33  4456599  2116
# 34  4440061  2117
# 35  4424504  2118
# 36  4409734  2119
# 37  4395580  2120
# 38  4382078  2121
# 39  4368763  2122
# 40  4355963  2123
# 41  4343180  2124
# 42  4330506  2125
# 43  4317936  2126
# 44  4305520  2127
# 45  4293066  2128
# 46  4280719  2129
# 47  4268302  2130
# 48  4255965  2131
# 49  4243699  2132
# 50  4231620  2133
# 51  4219796  2134
# 52  4208402  2135
# 53  4197487  2136
# 54  4187096  2137
# 55  4177197  2138
# 56  4168091  2139

# %%
befolkning_for_2023 = pd.read_csv("befolkning.csv")#.loc[lambda x: x.år <= 2022]

# %%
liste_med_fremskrivninger = [fremskrivning_1, fremskrivning_2, fremskrivning_3]

# %%
befolkning_for_2023
df1 = pd.DataFrame(befolkning_for_2023).loc[lambda x: x.år < 2024]

# %%
fremskrivning_1.loc[0,"år"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/python/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/python/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/python/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'år'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 fremskrivning_1.loc[0,"år"]
#
# File /opt/python/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File /opt/python/venv/lib/python3.10/site-packages/pandas/core/frame.py:3880, in DataFrame._get_value(self, index, col, takeable)
#    3877     series = self._ixs(col, axis=1)
#    3878     return series._values[index]
# -> 3880 series = self._get_item_cache(col)
#    3881 engine = self.index._engine
#    3883 if not isinstance(self.index, MultiIndex):
#    3884     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3885     #  results if our categories are integers that dont match our codes
#    3886     # IntervalIndex: IntervalTree has no get_loc
#
# File /opt/python/venv/lib/python3.10/site-packages/pandas/core/frame.py:4265, in DataFrame._get_item_cache(self, item)
#    4260 res = cache.get(item)
#    4261 if res is None:
#    4262     # All places that call _get_item_cache have unique columns,
#    4263     #  pending resolution of GH#33047
# -> 4265     loc = self.columns.get_loc(item)
#    4266     res = self._ixs(loc, axis=1)
#    4268     cache[item] = res
#
# File /opt/python/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'år'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df1['år'], df1['pop'], label='1986-2024', color='blue')
plt.plot(befolkning.år, befolkning["pop_1.5"]) 
# plt.plot(df1['år'], df1['pop'], label='1986-2024', color='blue')

for df in liste_med_fremskrivninger:
    print(df.head(1))
    plt.plot(df.år, df["2.1"], label=f"Fremskrivning fra {df.loc[0,'år']}")

plt.xlabel('År')
plt.ylabel('Befolkning')
plt.scatter(x=2025, y= befolkning.loc[lambda x: x.år == 2025]["pop_1.5"], color="red", s = 20, zorder = 5, label = "Første fremskrivning med TFR = 1.4")
plt.legend()
plt.ylim(0, 6.5e6)
#plt.grid(True)
plt.show()

# %%
bilder = Path("Figures") / "aldersfordeling"

# %%
plt.savefig(bilder / f"aldersutvikling.jpg", format="jpg", dpi=50)

# %%
popfordeling_2043-2140_tfr2_1.csv
