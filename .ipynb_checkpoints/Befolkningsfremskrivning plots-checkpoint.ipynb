# %%
import numpy as np
import random
import pandas as pd
from tqdm import tqdm
import os
import matplotlib.pyplot as plt
from pathlib import Path

# %%
data = Path("Data")

# %%
datafiler = os.listdir(data)
datafiler.sort()
datafiler
# Out:
# ['.ipynb_checkpoints',
#  'befolkningsutvikling_2023_2026_1_3-2_1-1_5.csv',
#  'befolkningsutvikling_2023_2123_1_3-2_1.csv',
#  'befolkningsutvikling_2023_2123_1_5.csv',
#  'befolkningsutvikling_2113_2123_1_5_v2.csv',
#  'popfordeling_2023-2023_tfr1_5.csv',
#  'popfordeling_2023-2026_tfr1_3.csv',
#  'popfordeling_2023-2026_tfr1_5.csv',
#  'popfordeling_2023-2026_tfr2_1.csv',
#  'popfordeling_2023-2033_tfr1_5.csv',
#  'popfordeling_2023-2123_tfr1_3.csv',
#  'popfordeling_2023-2123_tfr1_5.csv',
#  'popfordeling_2023-2123_tfr2_1.csv',
#  'popfordeling_2033-2043_tfr1_5.csv',
#  'popfordeling_2043-2053_tfr1_5.csv',
#  'popfordeling_2043-2140_tfr2_1.csv',
#  'popfordeling_2053-2063_tfr1_5.csv',
#  'popfordeling_2063-2073_tfr1_5.csv',
#  'popfordeling_2063-2140_tfr2_1.csv',
#  'popfordeling_2073-2083_tfr1_5.csv',
#  'popfordeling_2083-2093_tfr1_5.csv',
#  'popfordeling_2083-2140_tfr2_1.csv',
#  'popfordeling_2093-2103_tfr1_5.csv',
#  'popfordeling_2103-2113_tfr1_5.csv',
#  'popfordeling_2113-2123_tfr1_5.csv',
#  'populasjon_2023_tfr1_5.csv',
#  'populasjon_2026_tfr1_3.csv',
#  'populasjon_2026_tfr1_5.csv',
#  'populasjon_2026_tfr2_1.csv',
#  'populasjon_2033_tfr1_5.csv',
#  'populasjon_2043_tfr1_5.csv',
#  'populasjon_2053_tfr1_5.csv',
#  'populasjon_2063_tfr1_5.csv',
#  'populasjon_2073_tfr1_5.csv',
#  'populasjon_2083_tfr1_5.csv',
#  'populasjon_2093_tfr1_5.csv',
#  'populasjon_2103_tfr1_5.csv',
#  'populasjon_2113_tfr1_5.csv',
#  'populasjon_2123_tfr1_3.csv',
#  'populasjon_2123_tfr1_4.csv',
#  'populasjon_2123_tfr1_5.csv',
#  'populasjon_2123_tfr2_1.csv',
#  'populasjon_2140_tfr2_1.csv',
#  'utvikling_2043.csv',
#  'utvikling_2063.csv',
#  'utvikling_2083.csv']

# %%
befolkning = pd.read_csv(data / "befolkningsutvikling_2023_2123_1_5.csv").iloc[:,1:]
befolkning
# Out:
#        år  pop_1.5
# 0    2023  5488984
# 1    2024  5527175
# 2    2025  5565227
# 3    2026  5580903
# 4    2027  5596328
# ..    ...      ...
# 96   2119  3903653
# 97   2120  3873634
# 98   2121  3843801
# 99   2122  3814077
# 100  2123  3784535
#
# [101 rows x 2 columns]

# %%
populasjon_2026 = pd.read_csv(data / 'popfordeling_2023-2023_tfr1_5.csv')
populasjon_2026
# Out:
#     sex  alder  pop_2023
# 0     K      0   25310.0
# 1     K      1   28037.0
# 2     K      2   26820.0
# 3     K      3   27466.0
# 4     K      4   27692.0
# ..   ..    ...       ...
# 215   M    105      28.0
# 216   M    106       NaN
# 217   M    107       NaN
# 218   M    108       NaN
# 219   M    109       NaN
#
# [220 rows x 3 columns]

# %%
pop = pd.read_csv(data / 'popfordeling_2023-2033_tfr1_5.csv')
pop
# Out:
#     sex  alder  pop_2023  pop_2024  pop_2025  pop_2026  pop_2027  pop_2028
# 0     K      0   25310.0   27237.0   27123.0   26724.0   26911.0   26476.0  \
# 1     K      1   28037.0   25502.0   27419.0   27205.0   26816.0   26985.0
# 2     K      2   26820.0   28241.0   25725.0   27503.0   27284.0   26888.0
# 3     K      3   27466.0   27042.0   28423.0   25824.0   27586.0   27370.0
# 4     K      4   27692.0   27677.0   27254.0   28518.0   25915.0   27668.0
# ..   ..    ...       ...       ...       ...       ...       ...       ...
# 215   M    105      28.0       NaN       7.0       4.0       NaN       1.0
# 216   M    106       NaN      10.0       NaN       3.0       NaN       NaN
# 217   M    107       NaN       NaN       3.0       NaN       1.0       NaN
# 218   M    108       NaN       NaN       NaN       1.0       NaN       NaN
# 219   M    109       NaN       NaN       NaN       NaN       NaN       NaN
#
#      pop_2029  pop_2030  pop_2031  pop_2032  pop_2033
# 0     26278.0   26020.0   25814.0   25776.0   25696.0
# 1     26563.0   26353.0   26127.0   25900.0   25844.0
# 2     27074.0   26649.0   26433.0   26203.0   26004.0
# 3     26971.0   27142.0   26739.0   26497.0   26293.0
# 4     27442.0   27070.0   27225.0   26826.0   26590.0
# ..        ...       ...       ...       ...       ...
# 215       NaN       NaN       4.0       1.0       3.0
# 216       1.0       NaN       NaN       2.0       NaN
# 217       NaN       1.0       NaN       NaN       1.0
# 218       NaN       NaN       1.0       NaN       NaN
# 219       NaN       NaN       NaN       1.0       NaN
#
# [220 rows x 13 columns]

# %%
pop = pop[["sex","alder", "pop_2023", "pop_2033"]]

# %%
pop = pop.groupby("alder")[["pop_2023","pop_2033"]].sum()

# %%
pop.
# Out:
#        pop_2023  pop_2033
# alder
# 0       51991.0   51157.0
# 1       57415.0   51553.0
# 2       54778.0   52096.0
# 3       56455.0   52740.0
# 4       57146.0   53211.0
# ...         ...       ...
# 105       104.0       8.0
# 106         0.0       3.0
# 107         0.0       2.0
# 108         0.0       0.0
# 109         0.0       0.0
#
# [110 rows x 2 columns]

# %%
år = 2043

fremskrivning_1 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})

fremskrivning_1["år"] = range(år, år+ len(fremskrivning_21))
fremskrivning_1

# %%
år = 2063

fremskrivning_2 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})

fremskrivning_2["år"] = range(år, år+ len(fremskrivning_2))
fremskrivning_2

# %%
år = 2083

fremskrivning_3 = pd.read_csv(data / f"utvikling_{år}.csv").rename(columns={"0":"2.1"})

fremskrivning_3["år"] = range(år, år+ len(fremskrivning_3))
fremskrivning_3

# %%
befolkning_for_2023 = pd.read_csv("befolkning.csv")#.loc[lambda x: x.år <= 2022]

# %%
liste_med_fremskrivninger = [fremskrivning_1, fremskrivning_2, fremskrivning_3]

# %%
befolkning_for_2023
df1 = pd.DataFrame(befolkning_for_2023).loc[lambda x: x.år < 2024]

# %%
fremskrivning_1.loc[0,"år"]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df1['år'], df1['pop'], label='1986-2024', color='blue')
plt.plot(befolkning.år, befolkning["pop_1.5"]) 
# plt.plot(df1['år'], df1['pop'], label='1986-2024', color='blue')

for df in liste_med_fremskrivninger:
    print(df.head(1))
    plt.plot(df.år, df["2.1"], label=f"Fremskrivning fra {df.loc[0,'år']}")

plt.xlabel('År')
plt.ylabel('Befolkning')
plt.scatter(x=2025, y= befolkning.loc[lambda x: x.år == 2025]["pop_1.5"], color="red", s = 20, zorder = 5, label = "Første fremskrivning med TFR = 1.4")
plt.legend()
plt.ylim(0, 6.5e6)
#plt.grid(True)
plt.show()

# %%
bilder = Path("Figures") / "aldersfordeling"

# %%
plt.savefig(bilder / f"aldersutvikling.jpg", format="jpg", dpi=50)

# %%
popfordeling_2043-2140_tfr2_1.csv
