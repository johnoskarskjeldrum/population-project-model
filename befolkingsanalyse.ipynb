# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# '/home/jovyan'

# %%
data_path = Path("data")
popfordeling = pd.read_csv(data_path / "test_popfordeling_2023-2123_tfr1_5.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 data_path = Path("data")
# ----> 2 popfordeling = pd.read_csv(data_path / "test_popfordeling_2023-2123_tfr1_5.csv")
#
# ...

# %%
popfordeling
# Out:
#     sex  alder  pop_2023  pop_4047  pop_4048  pop_4049  pop_4050  pop_4051  \
# 0     K      0     253.0     273.0     278.0     262.0     244.0     248.0
# 1     K      1     280.0     253.0     273.0     278.0     262.0     244.0
# 2     K      2     268.0     280.0     253.0     273.0     278.0     262.0
# 3     K      3     275.0     268.0     280.0     253.0     273.0     278.0
# 4     K      4     277.0     275.0     268.0     280.0     253.0     273.0
# ..   ..    ...       ...       ...       ...       ...       ...       ...
# 215   M    105       NaN       NaN       NaN       NaN       NaN       NaN
# 216   M    106       NaN       NaN       NaN       NaN       NaN       NaN
# 217   M    107       NaN       NaN       NaN       NaN       NaN       NaN
# 218   M    108       NaN       NaN       NaN       NaN       NaN       NaN
# 219   M    109       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...
